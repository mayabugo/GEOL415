# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fileName = "C:/Users/mayav/Desktop/GEOL415/LA_AQS_2023.csv"
pd.read_csv(fileName)
# Out:
#        State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 0               6           37         1103           68103    1  34.06659
# 1               6           37         1103           42602    3  34.06659
# 2               6           37         1103           62201    1  34.06659
# 3               6           37         1103           62101    1  34.06659
# 4               6           37         1103           42603    1  34.06659
# ...           ...          ...          ...             ...  ...       ...
# 22155           6           37         1103           63301    1  34.06659
# 22156           6           37         1103           61104    1  34.06659
# 22157           6           37         1103           61103    1  34.06659
# 22158           6           37         1103           62201    1  34.06659
# 22159           6           37         1103           62101    1  34.06659
#
# ...

# %%
df = pd.read_csv(fileName)

# %%
display(df['Parameter Name'].to_string())
# Out:
# '0                         Ambient Min Temperature\n1                          Nitrogen dioxide (NO2)\n2                               Relative Humidity\n3                             Outdoor Temperature\n4                        Oxides of nitrogen (NOx)\n5                         Wind Direction - Scalar\n6                        Sample Min Baro Pressure\n7                      Wind Direction - Resultant\n8                        Sample Max Baro Pressure\n9                             Elapsed Sample Time\n10                    Average Ambient Temperature\n11                        Ambient Max Temperature\n12                          Ultraviolet radiation\n13                                Solar radiation\n14                           Sample Flow Rate- CV\n15                            Wind Speed - Scalar\n16                         Wind Speed - Resultant\n17                       Average Ambient Pressure\n18                                  Sample Volume\n19                         N
# ...

# %%
df_O3 = df[(df['Parameter Name']=='Ozone')&(df['Duration Description']=='1 HOUR')]
df_O3.head()
# Out:
#      State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 20            6           37         1103           44201    1  34.06659
# 64            6           37         1103           44201    1  34.06659
# 204           6           37         1103           44201    1  34.06659
# 228           6           37         1103           44201    1  34.06659
# 271           6           37         1103           44201    1  34.06659
#
#      Longitude  Datum Parameter Name Duration Description  ... AQI  \
# 20  -118.22688  WGS84          Ozone               1 HOUR  ...   .
# 64  -118.22688  WGS84          Ozone               1 HOUR  ...   .
# 204 -118.22688  WGS84          Ozone               1 HOUR  ...   .
# 228 -118.22688  WGS84          Ozone               1 HOUR  ...   .
# 271 -118.22688  WGS84          Ozone               1 HOUR  ...   .
#
#     Daily Criteria Indicator  Tribe Name  State Name  County Name  \
# ...

# %%
df_O3["Date (Local)"] = pd.to_datetime(df_O3["Date (Local)"])

# %%
date = df_O3["Date (Local)"]
value = df_O3["Arithmetic Mean"]

# %%
import seaborn as sns

# %%
sns.set_theme(style="darkgrid")
fig, ax = plt.subplots(figsize = (15,5))
sns.scatterplot(x=df_O3["Date (Local)"], y=df_O3["Arithmetic Mean"]*1000, data=df_O3)
# Out:
# <Axes: xlabel='Date (Local)', ylabel='Arithmetic Mean'>

# %%
# Finding the number of days where the O3 concentration is above 35 ppbv is

# %%
df_O3[df_O3["Arithmetic Mean"]>0.035]
# Out:
#        State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 4651            6           37         1103           44201    1  34.06659
# 4928            6           37         1103           44201    1  34.06659
# 5235            6           37         1103           44201    1  34.06659
# 7130            6           37         1103           44201    1  34.06659
# 7337            6           37         1103           44201    1  34.06659
# 7679            6           37         1103           44201    1  34.06659
# 7883            6           37         1103           44201    1  34.06659
# 8427            6           37         1103           44201    1  34.06659
# 8447            6           37         1103           44201    1  34.06659
# 9439            6           37         1103           44201    1  34.06659
# 9646            6           37         1103           44201    1  34.06659
# ...

# %%
#43 times

# %%
# finding when monitor has highest O3

# %%
df_O3.max()
# Out:
# State Code                                                     6
# County Code                                                   37
# Site Number                                                 1103
# Parameter Code                                             44201
# POC                                                            1
# Latitude                                                34.06659
# Longitude                                             -118.22688
# Datum                                                      WGS84
# Parameter Name                                             Ozone
# Duration Description                                      1 HOUR
# Pollutant Standard                             Ozone 1-hour 1979
# Date (Local)                                 2023-09-30 00:00:00
# Year                                                        2023
# Day In Year (Local)                1970-01-01 00:00:00.000000273
# ...

# %%
df_O3[df_O3["Arithmetic Mean"]==0.04575]
# Out:
#        State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 12292           6           37         1103           44201    1  34.06659
#
#        Longitude  Datum Parameter Name Duration Description  ... AQI  \
# 12292 -118.22688  WGS84          Ozone               1 HOUR  ...   .
#
#       Daily Criteria Indicator  Tribe Name  State Name  County Name  \
# 12292                        Y         NaN  California  Los Angeles
#
#          City Name                Local Site Name  \
# 12292  Los Angeles  Los Angeles-North Main Street
#
#                            Address                    MSA or CBSA Name  \
# 12292  1630 N MAIN ST, LOS ANGELES  Los Angeles-Long Beach-Anaheim, CA
#
#          Data Source
# 12292  AQS Data Mart
#
# [1 rows x 34 columns]

# %%
display(df_O3[df_O3["Arithmetic Mean"]==0.04575].to_string())
# Out:
# '       State Code  County Code  Site Number  Parameter Code  POC  Latitude  Longitude  Datum Parameter Name Duration Description Pollutant Standard Date (Local)  Year           Day In Year (Local)   Units of Measure Exceptional Data Type  Nonreg Observation Count  Observation Count  Observation Percent  Nonreg Arithmetic Mean  Arithmetic Mean  Nonreg First Maximum Value  First Maximum Value  First Maximum Hour AQI Daily Criteria Indicator  Tribe Name  State Name  County Name    City Name                Local Site Name                      Address                    MSA or CBSA Name    Data Source\n12292           6           37         1103           44201    1  34.06659 -118.22688  WGS84          Ozone               1 HOUR  Ozone 1-hour 1979   2023-05-14  2023 1970-01-01 00:00:00.000000134  Parts per million                   NaN                       NaN                 24                100.0                     NaN          0.04575                         NaN                0.07
# ...

# %%
# the day it was highest is 2023-05-14
